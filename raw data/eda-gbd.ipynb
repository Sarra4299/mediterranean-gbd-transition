# %% [markdown]
# # Mediterranean GBD Disease Burden Transition
# ### Comparative analysis of disease burden shift in Tunisia and Mediterranean neighbors

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from matplotlib.ticker import PercentFormatter

# %% [markdown]
# ## Section 1: Exploratory data analysis
# In this section, the GBD dataset is loaded and basic checks are performed to verify the data was loaded correctly.
# Some typical verification include:
# -Checking the shape of the dataset: if the numbers of columns and columns load correctly
# -Checking the column names of the dataset
# -Information section to check datatypes and null values
# -Checking unique values in key columns of the dataset

# %%
#reading the gbd csv data file
gbd_df = pd.read_csv("../data/gbd-data.csv")
gbd_df.head()
# Out:
#    population_group_id population_group_name  measure_id  \
# 0                    1        All Population           2
# 1                    1        All Population           2
# 2                    1        All Population           2
# 3                    1        All Population           2
# 4                    1        All Population           2
#
#                              measure_name  location_id location_name  sex_id  \
# 0  DALYs (Disability-Adjusted Life Years)          141         Egypt       3
# 1  DALYs (Disability-Adjusted Life Years)          154       Tunisia       3
# 2  DALYs (Disability-Adjusted Life Years)           86         Italy       3
# 3  DALYs (Disability-Adjusted Life Years)           86         Italy       3
# 4  DALYs (Disability-Adjusted Life Years)           86         Italy       3
#
#   sex_name  age_id  age_name  cause_id                    cause_name  \
# 0     Both      22  All ages       491       Cardiovascular diseases
# 1     Both      22  All ages       974  Diabetes and kidney diseases
# 2     Both      22  All ages       491       Cardiovascular diseases
# 3     Both      22  All ages       491       Cardiovascular diseases
# 4     Both      22  All ages       974  Diabetes and kidney diseases
#
#    metric_id metric_name  year       val     upper     lower
# 0          2     Percent  1990  0.175735  0.204860  0.152183
# 1          2     Percent  1990  0.038285  0.046878  0.030722
# 2          2     Percent  1991  0.219402  0.239270  0.198262
# 3          2     Percent  1990  0.219066  0.239085  0.198096
# 4          2     Percent  1991  0.038860  0.041750  0.036021

# %%
#checking the shape (rowsxcols) of data
gbd_df.shape

# %%
#checking column names of the csv data
gbd_df.columns

# %%
#checking information
gbd_df.info()

# %%
#checking unique values in cause_name to get exact strings for filtering
display(gbd_df["cause_name"].unique())

#checking unique values in location_name to get exact strings for filtering
display(gbd_df["location_name"].unique())

# %% [markdown]
# ## Section 2: Visualisation
# This section starts by analyzing the changes of the different chronic and infectious diseases across the years in Tunisia.

# %%
#creating Tunisia dataframe
tunisia_df = gbd_df[gbd_df["location_name"]== "Tunisia"].copy()
tunisia_df.head()
# Out:
#     population_group_id population_group_name  measure_id  \
# 1                     1        All Population           2
# 10                    1        All Population           2
# 12                    1        All Population           2
# 13                    1        All Population           2
# 16                    1        All Population           2
#
#                               measure_name  location_id location_name  sex_id  \
# 1   DALYs (Disability-Adjusted Life Years)          154       Tunisia       3
# 10  DALYs (Disability-Adjusted Life Years)          154       Tunisia       3
# 12  DALYs (Disability-Adjusted Life Years)          154       Tunisia       3
# 13  DALYs (Disability-Adjusted Life Years)          154       Tunisia       3
# 16  DALYs (Disability-Adjusted Life Years)          154       Tunisia       3
#
#    sex_name  age_id  age_name  cause_id  \
# 1      Both      22  All ages       974
# 10     Both      22  All ages       543
# 12     Both      22  All ages       956
# 13     Both      22  All ages       961
# 16     Both      22  All ages       491
#
#                                  cause_name  metric_id metric_name  year  \
# 1              Diabetes and kidney diseases          2     Percent  1990
# 10  Alzheimer's disease and other dementias          2     Percent  1990
# 12  Respiratory infections and tuberculosis          2     Percent  1990
# 13                Other infectious diseases          2     Percent  1990
# 16                  Cardiovascular diseases          2     Percent  1990
#
#          val     upper     lower
# 1   0.038285  0.046878  0.030722
# 10  0.007006  0.016110  0.002835
# 12  0.103092  0.127806  0.082952
# 13  0.032181  0.043588  0.022986
# 16  0.090403  0.111139  0.068657

# %%
#setting dimesnions of the plot
plt.figure(figsize = (12, 6))

#drawing the plot
tn_plot= sns.lineplot(
    data= tunisia_df,
    x = "year", 
    y="val", 
    hue= "cause_name")

#title of the figure 
tn_plot.set_title("Disease Burden Shift in Tunisia (1990–2023)")

#set label for x axis
tn_plot.set_xlabel("Year", size= 12)

#set label for y axis
tn_plot.set_ylabel("DALY percentage (%)", size = 12)
tn_plot.yaxis.set_major_formatter(mtick.PercentFormatter(1))
#set label for the hue
plt.legend(title = "Disease", loc= "upper left")

plt.show()
